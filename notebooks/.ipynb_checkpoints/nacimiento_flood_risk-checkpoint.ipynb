# %% [markdown]
# # Flood Risk Assessment - Nacimiento, Biobío Region, Chile
# ## Hydrological and hydraulic analysis of the Biobío and Vergara rivers
# ### Author: Constanza Morales | 2026

# %% [markdown]
# ## 1. Introduction
#
# This notebook replicates the flood risk methodology applied in Nacimiento, Chile,
# using open data and Python. The study area covers the confluence of the Biobío and
# Vergara rivers. Three zones were analyzed: Ribera Sur Río Biobío (extreme hazard),
# Ribera Oriente Río Vergara (significant hazard), and Fundo Los Tralpenes (no hazard).
#
# **Return periods analyzed:** 5, 25, 50 and 100 years
# **Manning coefficients:** Biobío n=0.054 | Vergara n=0.032
# **Hazard classification:** DEFRA 2006 methodology

# %%
# Libraries
import ee
import geemap
import geopandas as gpd
import rasterio
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Initialize Google Earth Engine
ee.Initialize(project='earth-engine-portfolio-498609')
print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %% [markdown]
# ## 2. Study Area Parameters
#
# Key hydrological parameters extracted from the original thesis (Morales, 2021).

# %%
# Flow rates (m3/s) for each return period - DGA Station Rio Biobio en Coihue
biobio_flows = {
    5:   753.31,
    25: 1071.99,
    50: 1197.62,
    100: 1319.39
}

# Flow rates (m3/s) for Vergara river
vergara_flows = {
    5:   59.79,
    25:  79.49,
    50:  89.08,
    100: 96.65
}

# Manning coefficients
n_biobio  = 0.054
n_vergara = 0.032

print("Parameters loaded successfully")
print(f"Biobio - Q100: {biobio_flows[100]} m3/s | Manning n: {n_biobio}")
print(f"Vergara - Q100: {vergara_flows[100]} m3/s | Manning n: {n_vergara}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Parameters loaded successfully
# Biobio - Q100: 1319.39 m3/s | Manning n: 0.054
# Vergara - Q100: 96.65 m3/s | Manning n: 0.032

# %% [markdown]
# ## 3. Flow Rate Analysis by Return Period

# %%
# Return periods
return_periods = [5, 25, 50, 100]

# Flow rates for both rivers
biobio_q  = [biobio_flows[tr] for tr in return_periods]
vergara_q = [vergara_flows[tr] for tr in return_periods]

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

x = range(len(return_periods))
width = 0.35

ax.bar([i - width/2 for i in x], biobio_q,  width, label='Biobío River',  color='steelblue')
ax.bar([i + width/2 for i in x], vergara_q, width, label='Vergara River', color='coral')

ax.set_xlabel('Return Period (years)')
ax.set_ylabel('Maximum Flow Rate (m³/s)')
ax.set_title('Maximum Flow Rates by Return Period - Nacimiento')
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## 4. Flood Hazard Index (HR)
#
# Hazard classification based on DEFRA 2006 methodology.
# Formula: HR = d * (v + 0.5) + DF
# Where: d = flood depth (m), v = flow velocity (m/s), DF = debris factor

# %%
# DEFRA 2006 hazard classification
def classify_hazard(hr):
    if hr < 0.75:
        return 'Low'
    elif hr < 1.25:
        return 'Moderate'
    elif hr < 2.5:
        return 'Significant'
    else:
        return 'Extreme'

# Scenario parameters from thesis (depth and velocity estimates per return period)
# Biobio river - Ribera Sur
scenarios = {
    'Return Period': [5, 25, 50, 100],
    'Depth_m':       [0.8, 1.2, 1.5, 1.8],
    'Velocity_ms':   [1.2, 1.8, 2.1, 2.4],
    'DF':            [1.0, 1.0, 1.0, 1.0]
}

# Calculate HR for each scenario
import pandas as pd

df = pd.DataFrame(scenarios)
df['HR'] = df['Depth_m'] * (df['Velocity_ms'] + 0.5) + df['DF']
df['Hazard Class'] = df['HR'].apply(classify_hazard)

print(df.to_string(index=False))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#  Return Period  Depth_m  Velocity_ms  DF   HR Hazard Class
#              5      0.8          1.2 1.0 2.36  Significant
#             25      1.2          1.8 1.0 3.76      Extreme
# ...

# %% [markdown]
# Note: Depth and velocity values are representative estimates based on the thesis
# results. Exact values were obtained from HEC-RAS hydraulic modeling (Morales, 2021).

# %%
# Visualize HR by return period
colors = {'Low': 'green', 'Moderate': 'yellow', 
          'Significant': 'orange', 'Extreme': 'red'}

bar_colors = [colors[h] for h in df['Hazard Class']]

fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(df['Return Period'].astype(str), df['HR'], color=bar_colors)

# Threshold lines
ax.axhline(y=0.75, color='gray', linestyle='--', label='Low limit')
ax.axhline(y=1.25, color='yellow', linestyle='--', label='Moderate limit')
ax.axhline(y=2.5,  color='orange', linestyle='--', label='Significant limit')

ax.set_xlabel('Return Period (years)')
ax.set_ylabel('Hazard Rating (HR)')
ax.set_title('Flood Hazard Index - South Bank Biobío River')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## 5. Interactive Map - Study Area
# Map of Nacimiento showing the flood risk zones along the Biobío and Vergara rivers.

# %%
import ee
import geemap

# Initialize GEE
ee.Initialize(project='earth-engine-portfolio-498609')

# --- 1. Study area: Nacimiento commune boundary (FAO GAUL) ---
nacimiento = ee.FeatureCollection("FAO/GAUL/2015/level2") \
    .filter(ee.Filter.eq('ADM2_NAME', 'Nacimiento'))

# --- 2. Rivers from HydroSHEDS ---
rivers = ee.FeatureCollection("WWF/HydroSHEDS/v1/FreeFlowingRivers") \
    .filterBounds(nacimiento.geometry())

# --- 3. Flood risk zones - digitized from satellite imagery ---

# South Bank Biobio River - north section
biobio_zone_1 = ee.Geometry.Polygon([[
    [-72.679460, -37.483591],
    [-72.684354, -37.478823],
    [-72.685899, -37.475417],
    [-72.685899, -37.472216],
    [-72.688990, -37.472216],
    [-72.689591, -37.475417],
    [-72.688647, -37.477665],
    [-72.687273, -37.479913],
    [-72.685899, -37.481548],
    [-72.684096, -37.483114],
    [-72.681005, -37.483932],
    [-72.679460, -37.483591]
]])

# South Bank Biobio River - south section
biobio_zone_2 = ee.Geometry.Polygon([[
    [-72.665204, -37.501188],
    [-72.664861, -37.499214],
    [-72.664603, -37.497443],
    [-72.664088, -37.494924],
    [-72.666063, -37.492472],
    [-72.668209, -37.490293],
    [-72.670527, -37.489271],
    [-72.672330, -37.489067],
    [-72.673875, -37.488671],
    [-72.672630, -37.489727],
    [-72.671471, -37.490340],
    [-72.670140, -37.491225],
    [-72.669239, -37.492179],
    [-72.667908, -37.493881],
    [-72.666921, -37.495992],
    [-72.666277, -37.497116],
    [-72.665848, -37.498886],
    [-72.665204, -37.501188]
]])

# East Bank Vergara River - north section
vergara_zone_1 = ee.Geometry.Polygon([[
    [-72.663137, -37.497035],
    [-72.660648, -37.498533],
    [-72.655840, -37.500235],
    [-72.654723, -37.505410],
    [-72.646224, -37.507997],
    [-72.645279, -37.506499],
    [-72.642703, -37.507929],
    [-72.643820, -37.509972],
    [-72.649229, -37.511402],
    [-72.666743, -37.509359],
    [-72.665456, -37.504116],
    [-72.663996, -37.500575],
    [-72.663137, -37.497035]
]])

# East Bank Vergara River - south section
vergara_zone_2 = ee.Geometry.Polygon([[
    [-72.666879, -37.509447],
    [-72.667415, -37.510860],
    [-72.667394, -37.512953],
    [-72.667480, -37.514853],
    [-72.666621, -37.518665],
    [-72.665976, -37.522771],
    [-72.666577, -37.526038],
    [-72.661855, -37.529373],
    [-72.660567, -37.527944],
    [-72.662885, -37.524609],
    [-72.662370, -37.521205],
    [-72.663229, -37.517529],
    [-72.662628, -37.516644],
    [-72.663658, -37.515350],
    [-72.663229, -37.513240],
    [-72.662715, -37.510019],
    [-72.666879, -37.509447]
]])

# Fundo Los Tralpenes - no flood hazard
tralpenes_zone = ee.Geometry.Polygon([[
    [-72.645279, -37.506499],
    [-72.643648, -37.499554],
    [-72.641158, -37.499690],
    [-72.638153, -37.500235],
    [-72.637294, -37.502618],
    [-72.634719, -37.503776],
    [-72.632486, -37.503231],
    [-72.631542, -37.502346],
    [-72.630254, -37.503367],
    [-72.629481, -37.505819],
    [-72.628709, -37.507725],
    [-72.628795, -37.509427],
    [-72.629481, -37.510653],
    [-72.631456, -37.512014],
    [-72.633087, -37.512491],
    [-72.636779, -37.513104],
    [-72.640471, -37.513444],
    [-72.643219, -37.513580],
    [-72.645966, -37.513853],
    [-72.649057, -37.511402],
    [-72.643787, -37.509958],
    [-72.642692, -37.507915],
    [-72.645279, -37.506499]
]])

# --- 4. Create interactive map ---
Map = geemap.Map(center=[-37.500, -72.660], zoom=13)

# Satellite basemap
Map.add_basemap('Esri.WorldImagery')

# Commune boundary
Map.addLayer(
    nacimiento,
    {'color': 'white', 'fillColor': '00000000'},
    'Nacimiento Commune'
)

# Rivers
Map.addLayer(
    rivers,
    {'color': '0000FF', 'width': 2},
    'Rivers (HydroSHEDS)'
)

# Flood hazard zones
Map.addLayer(
    ee.FeatureCollection([ee.Feature(biobio_zone_1)]),
    {'color': 'red', 'fillColor': 'FF000066'},
    'South Bank Biobio River - Extreme Hazard (85%)'
)

Map.addLayer(
    ee.FeatureCollection([ee.Feature(biobio_zone_2)]),
    {'color': 'red', 'fillColor': 'FF000066'},
    'South Bank Biobio River - Confluence Zone'
)

Map.addLayer(
    ee.FeatureCollection([ee.Feature(vergara_zone_1)]),
    {'color': 'orange', 'fillColor': 'FFA50066'},
    'East Bank Vergara River - Significant Hazard (32.7%)'
)

Map.addLayer(
    ee.FeatureCollection([ee.Feature(vergara_zone_2)]),
    {'color': 'orange', 'fillColor': 'FFA50066'},
    'East Bank Vergara River - South Section'
)

Map.addLayer(
    ee.FeatureCollection([ee.Feature(tralpenes_zone)]),
    {'color': 'green', 'fillColor': '00800033'},
    'Fundo Los Tralpenes - No Flood Hazard'
)

# City labels on top
Map.add_basemap('CartoDB.PositronOnlyLabels')
Map.addLayerControl()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-37.5, -72.66], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright…

# %%
# Export interactive map to HTML
Map.to_html('nacimiento_flood_map.html')
print("Map exported successfully")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map exported successfully

# %% [markdown]
# ## 6. Conclusions
#
# - **South Bank Biobío River (Ribera Sur):** 85% of the area presents significant to
# extreme flood hazard. Only 4.1% of the flooded surface corresponds to urban land use.
# - **East Bank Vergara River (Ribera Oriente):** 32.7% of the area presents significant
# to extreme flood hazard. Flooded sectors include 56.5% agricultural/forest land,
# 42.4% industrial use, and 1.1% urban area.
# - **Fundo Los Tralpenes:** Outside flood risk for all return periods studied (TR5–TR100).
# - Hazard increases with return period, but minimally — only 2% between TR5 and TR100.
# - Average hazard distribution across all scenarios: 47% extreme, 35% significant,
# 2.5% moderate.
# - An estimated 200 people (0.7% of total communal population) are exposed to flood risk,
# corresponding to 40 houses within the hazard zone.
# - Both Ribera Sur Río Biobío and Ribera Oriente Río Vergara are **not suitable for
# construction of any kind** due to extreme flood hazard classification.
#
# *Based on: Morales, C. (2021). Flood Risk Assessment - Nacimiento, Biobío Region,
# Chile. UCSC. Methodology: DEFRA 2006.*
